# %% [markdown]
# 1. Question: Please refer the table below to answer below questions:
# |Planned to purchase Product A| Actually placed and order for Product A - Yes| Actually placed and order for Product A - No|Total|
# |--|--|--|--|
# |Yes|400|100|500|
# |No|200|1300|1500|
# |Total|600|1400|2000|
#
#  1. Refer to the above table and find the joint probability of the people who planned to purchase and actually
#   placed an order.
#  2. Refer to the above table and find the joint probability of the people who planned to purchase and actually
#   placed an order, given that people planned to purchase

# %%
#Q.1.A) Refer to the above table and find the joint probability of the people who planned to purchase and actually
#   placed an order.
# 400 people planned to purchase and actually placed an order is 400 out of 2000 people.
# X is the number of people who planned and actually placed an order
# T is total number of people
X = 400
T  = 2000
Prob = round(X / T,4) 
print('Joint probability of the people who planned to purchase and actually placed an order = %1.4f' % Prob)
# Out:
# Joint probability of the people who planned to purchase and actually placed an order = 0.2000

# %%
# Q.1.B) Refer to the above table and find the joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase
# P1 = P(Actually placed an order | Planned to purchase)

P1   = (400 / 2000 )/ (500 / 2000)

print('P(Actually placed an order | Planned to purchase) = %1.4f' % P1)
# Out:
# P(Actually placed an order | Planned to purchase) = 0.8000

# %% [markdown]
# 2. Question: An electrical manufacturing company conducts quality checks at specified periods on the
# products it manufactures. Historically, the failure rate for the manufactured item is 5%. Suppose a random
# sample of 10 manufactured items is selected. Answer the following questions.
#
# A. Probability that none of the items are defective?
#
# B. Probability that exactly one of the items is defective?
#
# C. Probability that two or fewer of the items are defective?
#
# D. Probability that three or more of the items are defective?

# %%
import numpy             as np
import pandas            as pd
import scipy.stats       as stats
import matplotlib.pyplot as plt

# %%
p   =  0.05 # the failure rate for the manufactured item is 5%
n   =  10 # sample size
k   =  np.arange(0,11) # An array of quantiles

# %%
binomial = stats.binom.pmf(k,n,p)
binomial
# Out:
# array([5.98736939e-01, 3.15124705e-01, 7.46347985e-02, 1.04750594e-02,
#        9.64808106e-04, 6.09352488e-05, 2.67259863e-06, 8.03789063e-08,
#        1.58642578e-09, 1.85546875e-11, 9.76562500e-14])

# %%
#A. Probability that none of the items are defective?
print('Probability that none of the items are defective = %1.4f' % binomial[0])
# Out:
# Probability that none of the items are defective = 0.5987

# %%
#B. Probability that exactly one of the items is defective?
print('Probability that exactly one of the items is defective = %1.4f' % binomial[1])
# Out:
# Probability that exactly one of the items is defective = 0.3151

# %%
cumbinomial = stats.binom.cdf(k,n,p)
cumbinomial
# Out:
# array([0.59873694, 0.91386164, 0.98849644, 0.9989715 , 0.99993631,
#        0.99999725, 0.99999992, 1.        , 1.        , 1.        ,
#        1.        ])

# %%
cumbinomial = stats.binom.cdf(k,n,p)
cumbinomial
# Out:
# array([0.59873694, 0.91386164, 0.98849644, 0.9989715 , 0.99993631,
#        0.99999725, 0.99999992, 1.        , 1.        , 1.        ,
#        1.        ])

# %%
#C. Probability that two or fewer of the items are defective?
print('Probability that two or fewer of the items are defective = %1.4f' %cumbinomial[2])
# Out:
# Probability that two or fewer of the items are defective = 0.9885

# %%
#D. Probability that three or more of the items are defective?
print('Probability that three or more of the items are defective = %1.4f' %(1- cumbinomial[2]))
# Out:
# Probability that three or more of the items are defective = 0.0115

# %% [markdown]
# 3. Question: A car salesman sells on an average 3 cars per week.
# A. Probability that in a given week he will sell some cars.
# B. Probability that in a given week he will sell 2 or more but less than 5 cars.
# C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold perweek.

# %%
rate =  3 # which is the mean
n    =  np.arange(0,16)
cumpoisson = stats.poisson.cdf(n,rate)
cumpoisson
# Out:
# array([0.04978707, 0.19914827, 0.42319008, 0.64723189, 0.81526324,
#        0.91608206, 0.96649146, 0.9880955 , 0.99619701, 0.99889751,
#        0.99970766, 0.99992861, 0.99998385, 0.9999966 , 0.99999933,
#        0.99999988])

# %%
# A. Probability that in a given week he will sell some cars.
print('Probability that in a given week salesman will sell some cars = %1.4f' %(1 - cumpoisson[0]))
# Out:
# Probability that in a given week salesman will sell some cars = 0.9502

# %%
#B. Probability that in a given week he will sell 2 or more but less than 5 cars.
# Let P1 be the probability that the salesman sells more than 4 cars
P1 = cumpoisson[4] # P(X >=4)
# Let P2 be the probability that the salesman sells more than 1 car
P2 = cumpoisson[1] # P(X >=1)
print('Probability that in a given week he will sell 2 or more but less than 5 cars = %1.4f' % (P1-P2))
# Out:
# Probability that in a given week he will sell 2 or more but less than 5 cars = 0.6161

# %%
#C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold perweek.
poisson = stats.poisson.pmf(n,rate)
plt.plot(n,poisson, 'o-')
plt.title('Poisson')
plt.xlabel('Number of Cars sold per week')
plt.ylabel('Cumulative Prob of Cars sold per week')
plt.show()

# %% [markdown]
# 4. Question: Accuracy in understanding orders for a speech based bot at a restaurant is important for the
# Company X which has designed, marketed and launched the product for a contactless delivery due to the
# COVID-19 pandemic. Recognition accuracy that measures the percentage of orders that are taken correctly is 86.8%.
# Suppose that you place order with the bot and two friends of yours independently place orders with
# the same bot. Answer the following questions.
#
# A. What is the probability that all three orders will be recognised correctly?
#
#
# B. What is the probability that none of the three orders will be recognised correctly?
#
# C. What is the probability that at least two of the three orders will be recognised correctly?

# %%
import numpy             as np
import pandas            as pd
import scipy.stats       as stats
import matplotlib.pyplot as plt
p = 0.868 #probability of orders that are taken correctly
n = 3
k = np.arange(0,4)

# %%
binomial = stats.binom.pmf(k,n,p)
binomial
# Out:
# array([0.00229997, 0.0453721 , 0.2983559 , 0.65397203])

# %%
#A. What is the probability that all three orders will be recognised correctly?
print('The probability that all three orders will be recognised correctly = %1.4f' %binomial[3])
# Out:
# The probability that all three orders will be recognised correctly = 0.6540

# %%
#B. What is the probability that none of the three orders will be recognised correctly?
print('The probability that none of three orders will be recognised correctly = %1.4f' %binomial[0])
# Out:
# The probability that none of three orders will be recognised correctly = 0.0023

# %%
#C. What is the probability that at least two of the three orders will be recognised correctly?
cumbinomial = stats.binom.cdf(k,n,p)
print(' the probability that at least two of the three orders will be recognised correctly = %1.4f' %(1 - cumbinomial[1]))
# Out:
#  the probability that at least two of the three orders will be recognised correctly = 0.9523

# %% [markdown]
# 5. Question: A group of 300 professionals sat for a competitive exam. The results show the information of
# marks obtained by them have a mean of 60 and a standard deviation of 12. The pattern of marks follows a
# normal distribution. Answer the following questions.
#
# A. What is the percentage of students who score more than 80.
#
# B. What is the percentage of students who score less than 50.
#
# C. What should be the distinction mark if the highest 10% of students are to be awarded distinction?

# %%
z = (80 - 60)/12
p1 = 1 - (stats.norm.cdf(z))
p = p1*100 # percentage of students who score more than 80
print('The percentage of students who score more than 80 = %1.4f' %p)
# Out:
# The percentage of students who score more than 80 = 4.7790

# %%
z = (50 - 60)/12
p = stats.norm.cdf(z)*100
#p = p1*100 # percentage of students who score less than 50
print('The percentage of students who score less than 50 = %1.4f' %p)
# Out:
# The percentage of students who score less than 50 = 20.2328

# %%
# Z score for 10% = 1.28 from z-score percentile for normal distribution table
z=1.28
#z = (x-mean)/deviation
#1.28 = (x-60)/12
x = (1.28*12)+60
print('The distinction mark if the highest 10% of students are to be awarded distinction = ', round(x,2))
# Out:
# The distinction mark if the highest 10% of students are to be awarded distinction =  75.36

# %% [markdown]
# 6. Question: Explain 1 real life industry scenario [other than the ones mentioned above] where you can use the
# concepts learnt in this module of Applied statistics to get a data driven business solution.
#
# Answer :
#     Uber data analysis is a real life scenario where we can use the applied statistics. Using Descriptive
#     statistics we get information about peak hours,price estimation,mostly preferred location,weekdays
#     analysis,weekend analysis.Also we have got strong correlation between distance & fair. Using descriptive
#     information we make inferences about peak hours,frequency of rides,location,etc.

# %% [markdown]
# PART TWO : BASKKET BALL
# 1. Read the data set, clean the data and prepare a final dataset to be used for analysis.

# %%
# Basketball
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Basketball.csv")
data.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6   1931to32
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# ...

# %%
data.info() #different types of data/variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     object
#  3   PlayedGames          61 non-null     object
#  4   WonGames             61 non-null     object
#  5   DrawnGames           61 non-null     object
#  6   LostGames            61 non-null     object
#  7   BasketScored         61 non-null     object
#  8   BasketGiven          61 non-null     object
#  9   TournamentChampion   61 non-null     object
#  10  Runner-up            61 non-null     object
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %%
data.shape #dimension of the dataset
# Out:
# (61, 13)

# %%
data.isnull().sum()
# Out:
# Team                   0
# Tournament             0
# Score                  0
# PlayedGames            0
# WonGames               0
# DrawnGames             0
# LostGames              0
# BasketScored           0
# BasketGiven            0
# TournamentChampion     0
# Runner-up              0
# TeamLaunch             0
# HighestPositionHeld    0
# dtype: int64

# %%
data.tail()
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     -           -        -          -         -
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  -         -    2009-10
# 57           37          57                  -         -    1956-57
# 58           51          85                  -         -    1951~52
# 59           34          65                  -         -    1955-56
# 60            -           -                  -         -    2017~18
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# ...

# %% [markdown]
# From above tail information we observed that tournamentchampion and runner-up cloumn has information which is non numeric or invalid data and last row(team 61) also not provide some correct data. Let us assume that '-' is zero for column as teams not get any championship or runnerup position.

# %%
data = data.replace('-','0')

# %% [markdown]
# 2. Perform detailed statistical analysis and EDA using univariate, bi-variate and multivariate EDA techniques to get a data
# driven insights on recommending which teams they can approach which will be a deal win for them.. Also as a data
# and statistics expert you have to develop a detailed performance report using this data.
# Hint: Use statistical techniques and visualisation techniques to come up with useful metrics and reporting. Find out
# the best performing team, oldest team, team with highest goals, team with lowest performance etc. and many more.
# These are just random examples please use your best analytical approach to build this report. You can mix match
# columns to create new ones which can be used for better analysis. Create your own features if required. Be highly
# experimental and analytical here to find hidden patterns. Use graphical interactive libraries to enable you to publish
# interactive plots in python.

# %%
df2 = data
df2['TeamLaunch'] = df2['TeamLaunch'].str[:4]
df2[['Score','PlayedGames','WonGames','DrawnGames','LostGames','BasketScored','BasketGiven','TournamentChampion','Runner-up','TeamLaunch']] = df2[['Score','PlayedGames','WonGames','DrawnGames','LostGames','BasketScored','BasketGiven','TournamentChampion','Runner-up','TeamLaunch']].apply(pd.to_numeric)
df2
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# ..      ...         ...    ...          ...       ...         ...        ...
# 56  Team 57           1     34           38         8          10         20
# 57  Team 58           1     22           30         7           8         15
# 58  Team 59           1     19           30         7           5         18
# 59  Team 60           1     14           30         5           4         21
# 60  Team 61           1      0            0         0           0          0
#
# ...

# %%
df2.dtypes
# Out:
# Team                   object
# Tournament              int64
# Score                   int64
# PlayedGames             int64
# WonGames                int64
# DrawnGames              int64
# LostGames               int64
# BasketScored            int64
# BasketGiven             int64
# TournamentChampion      int64
# Runner-up               int64
# TeamLaunch              int64
# HighestPositionHeld     int64
# dtype: object

# %%
df2['won_ratio'] = df2['WonGames']/df2['PlayedGames']
df2['Lost_ratio'] = df2['LostGames']/df2['PlayedGames']
df2
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# ..      ...         ...    ...          ...       ...         ...        ...
# 56  Team 57           1     34           38         8          10         20
# 57  Team 58           1     22           30         7           8         15
# 58  Team 59           1     19           30         7           5         18
# 59  Team 60           1     14           30         5           4         21
# 60  Team 61           1      0            0         0           0          0
#
# ...

# %%
df2.isnull().sum()
# Out:
# Team                   0
# Tournament             0
# Score                  0
# PlayedGames            0
# WonGames               0
# DrawnGames             0
# LostGames              0
# BasketScored           0
# BasketGiven            0
# TournamentChampion     0
# Runner-up              0
# TeamLaunch             0
# HighestPositionHeld    0
# won_ratio              1
# Lost_ratio             1
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.describe()
# Out:
#        Tournament        Score  PlayedGames     WonGames  DrawnGames  \
# count   60.000000    60.000000    60.000000    60.000000   60.000000
# mean    24.383333   916.450000   810.100000   309.033333  192.083333
# std     26.884620  1138.342899   877.465393   408.481395  201.985508
# min      1.000000    14.000000    30.000000     5.000000    4.000000
# 25%      4.000000   104.250000   115.500000    34.750000   26.250000
# 50%     12.000000   395.500000   424.500000   124.000000   98.500000
# 75%     39.000000  1360.500000  1345.500000   432.750000  331.500000
# max     86.000000  4385.000000  2762.000000  1647.000000  633.000000
#
#          LostGames  BasketScored  BasketGiven  TournamentChampion  Runner-up  \
# count    60.000000     60.000000    60.000000            60.00000  60.000000
# mean    308.816667   1159.350000  1159.233333             1.45000   1.433333
# std     294.508639   1512.063948  1163.946914             5.51554   4.574679
# ...

# %% [markdown]
# Won Ration is less than lost ratio

# %%
#Best Performing Team
df2[df2['won_ratio'] == df2['won_ratio'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
#
#    HighestPositionHeld  won_ratio  Lost_ratio
# 0                    1   0.596307    0.203838

# %% [markdown]
# Team 1 is best performing team

# %%
#oldest team
df2[df2['TeamLaunch'] == df2['TeamLaunch'].min()]
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 4    Team 5          86   3368         2762      1209         633        920
# 6    Team 7          82   2792         2626       948         608       1070
# 7    Team 8          70   2573         2302       864         577        861
# 13  Team 14          44   1416         1428       453         336        639
# 44  Team 45           7    107          130        43          21         66
# 51  Team 52           4     56           72        21          14         37
# 53  Team 54           3     42           54        18           6         30
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# ...

# %%
# highest played tournaments
df2[df2['Tournament'] == df2['Tournament'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 4  Team 5          86   3368         2762      1209         633        920
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
# 1          5900         3114                  25         25        1929
# 4          4631         3700                   8          7        1929
#
#    HighestPositionHeld  won_ratio  Lost_ratio
# 0                    1   0.596307    0.203838
# 1                    1   0.572411    0.220130
# 4                    1   0.437726    0.333092

# %%
# Highest Played games 
df2[df2['PlayedGames'] == df2['PlayedGames'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 4  Team 5          86   3368         2762      1209         633        920
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
# 1          5900         3114                  25         25        1929
# 4          4631         3700                   8          7        1929
#
#    HighestPositionHeld  won_ratio  Lost_ratio
# 0                    1   0.596307    0.203838
# 1                    1   0.572411    0.220130
# 4                    1   0.437726    0.333092

# %%
#team with highest goals
df2[df2['BasketScored'] == df2['BasketScored'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
#
#    HighestPositionHeld  won_ratio  Lost_ratio
# 0                    1   0.596307    0.203838

# %%
 #team with lowest performance
df2[df2['Score'] == df2['Score'].min()]
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 59  Team 60           1     14           30         5           4         21
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 59            34           65                   0          0        1955
#
#     HighestPositionHeld  won_ratio  Lost_ratio
# 59                   15   0.166667         0.7

# %%
# Team was maximun times Tournament Champion :
df2[df2['TournamentChampion'] == df2['TournamentChampion'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
#
#    HighestPositionHeld  won_ratio  Lost_ratio
# 0                    1   0.596307    0.203838

# %%
df2[df2['HighestPositionHeld'] == df2['HighestPositionHeld'].min()]
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# 5    Team 6          73   2819         2408       990         531        887
# 7    Team 8          70   2573         2302       864         577        861
# 9   Team 10          51   1884         1728       606         440        682
# 10  Team 11          45   1814         1530       563         392        575
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0           5947         3140                  33         23        1929
# ...

# %%
df2[df2['Score'] == df2['Score'].max()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
#
#    HighestPositionHeld  won_ratio  Lost_ratio
# 0                    1   0.596307    0.203838

# %%
sns.distplot(df2['Score'])
# Out:
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Score', ylabel='Density'>

# %%
sns.jointplot(df2['BasketScored'],df2['BasketGiven'])
# Out:
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df2['PlayedGames'],df2['WonGames'])
# Out:
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize =(40,10))
sns.barplot(df2['Team'],df2['TournamentChampion'])
# Out:
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Team', ylabel='TournamentChampion'>

# %%
sns.pairplot(df2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
corr = df2.corr()
corr
# Out:
#                      Tournament     Score  PlayedGames  WonGames  DrawnGames  \
# Tournament             1.000000  0.981258     0.998683  0.971749    0.989295
# Score                  0.981258  1.000000     0.979687  0.997232    0.958090
# PlayedGames            0.998683  0.979687     1.000000  0.967486    0.993972
# WonGames               0.971749  0.997232     0.967486  1.000000    0.939416
# DrawnGames             0.989295  0.958090     0.993972  0.939416    1.000000
# LostGames              0.949350  0.878780     0.955925  0.851436    0.972786
# BasketScored           0.974867  0.996634     0.969970  0.999312    0.942234
# BasketGiven            0.987781  0.943801     0.990020  0.925745    0.992479
# TournamentChampion     0.589304  0.715014     0.575072  0.752904    0.503378
# Runner-up              0.645924  0.764819     0.633101  0.797849    0.566021
# TeamLaunch            -0.599166 -0.538542    -0.581243 -0.540421   -0.570175
# ...

# %%
cov =df2.cov()
cov
# Out:
#                        Tournament         Score   PlayedGames       WonGames  \
# Tournament             722.782768  3.003033e+04  2.355925e+04   10671.614124
# Score                30030.333051  1.295825e+06  9.785666e+05  463704.696610
# PlayedGames          23559.249153  9.785666e+05  7.699455e+05  346774.216949
# WonGames             10671.614124  4.637047e+05  3.467742e+05  166857.049718
# DrawnGames            5372.170904  2.202924e+05  1.761669e+05   77508.658192
# LostGames             7516.715537  2.946126e+05  2.470312e+05  102428.853672
# BasketScored         39629.558475  1.715454e+06  1.286941e+06  617225.191525
# BasketGiven          30909.909040  1.250509e+06  1.011131e+06  440145.958192
# TournamentChampion      87.383898  4.489269e+03  2.783175e+03    1696.289831
# Runner-up               79.441243  3.982836e+03  2.541346e+03    1490.917514
# TeamLaunch            -429.234746 -1.633567e+04 -1.359038e+04   -5882.320339
# ...

# %%
plt.figure(figsize = (16,5))
sns.heatmap(corr, annot = True, linewidths= .5)
# Out:
# <AxesSubplot:>

# %%
df2['win_loss_ratio'] = df2['won_ratio']/df2['Lost_ratio']
df2
# Out:
# <ipython-input-31-0ca00153e46a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['win_loss_ratio'] = df2['won_ratio']/df2['Lost_ratio']
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# 5    Team 6          73   2819         2408       990         531        887
# ...

# %%
df2.nlargest(10, ['win_loss_ratio'])
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# 20  Team 21          17    970          646       266         172        208
# 5    Team 6          73   2819         2408       990         531        887
# 7    Team 8          70   2573         2302       864         577        861
# 10  Team 11          45   1814         1530       563         392        575
# 8    Team 9          58   2109         1986       698         522        766
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# ...

# %% [markdown]
# Above are top 10 teams according to their win_loss ratio. Company can approach these Teams which will be a deal win for them. quantative data is given, we require more information of teams for detail analysis.

# %% [markdown]
# 3. Please include any improvements or suggestions to the association management on quality, quantity, variety, velocity,
# veracity etc. on the data points collected by the association to perform a better data analysis in future

# %% [markdown]
# Quality : Data quality issues in Big Data is that the data includes several data types ( such as : structured, semi-structured, and unstructured) coming in from different data sources. Thus, often a single data quality metric will not be applicable for the entire data and so we need to separately define data quality metrics for each data type. Data that's of poor quality can increase data management costs as a result of frequent remediation, additional resource needs and compliance issues. It can also lead to impaired decision-making and business forecasting.
#
# Quantity : The main characteristic that makes data “big” is the sheer volume. It makes no sense to focus on minimum storage units because the total amount of information is growing exponentially every year.No one really knows how much new data is being generated, but the amount of information being collected is huge. This volume presents the most immediate challenge to conventional IT structures. It calls for scalable storage, and a distributed approach to querying. Many companies already have large amounts of archived data, perhaps in the form of logs, but not the capacity to process it.
#
# Variety : Data from different sources often has serious semantic differences. For example, “profit” can have widely varied definitions across the business units of an organization or external agencies. Thus, the fields with identical names may not mean the same thing. This problem is made worse by the lack of adequate and consistent meta-data from each data source. In order to make sense of data, you need reliable metadata (such as to make sense of sales numbers from a store, you need other information such as date-time, items purchased, coupons used, etc.). Usually, a lot of these data sources are outside an organization and thus, it is very hard to ensure good metadata for such data.
#
# Velocity : The tremendous pace of data generation and collection makes it incredibly hard to monitor data quality within a reasonable overhead on time and resources (storage, compute, human effort, etc.). So, by the time data quality assessment completes, the output might be outdated and of little use, particularly if the Big Data project is to serve any real-time or near real-time business needs. In such scenarios, we need to re-define data quality metrics so that they are relevant as well as feasible in the real-time context.
#
# Veracity: Veracity, one of the most overlooked Big Data characteristics, is directly related to data quality, as it refers to the inherent biases, noise and abnormality in data. Because of veracity, the data values might not be exact real values, rather they might be approximations. In other words, the data might have some inherent impreciseness and uncertainty. Besides data inaccuracies, Veracity also includes data consistency (defined by the statistical reliability of data) and data trustworthiness (based on data origin, data collection and processing methods, security infrastructure, etc.). These data quality issues in turn impact data integrity and data accountability.

# %% [markdown]
# Variety :  Variety refers to the many sources and types of data both structured and unstructured. We used to store data from sources like spreadsheets and databases. Now data comes in the form of emails, photos, videos, monitoring devices, PDFs, audio, etc. This variety of unstructured data creates problems for storage, mining and analyzing data.

# %% [markdown]
# PART THREE : STARTUP ECOSYSTEM
#
#
# 1. Data warehouse:
#
#     • Read the CSV file.

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Data warehouse:
# Read the csv file companyX_EU.csv

data1 = pd.read_csv('companyX_EU.csv')

# %%
data1
# Out:
#              Startup             Product Funding             Event  \
# 0             2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1               3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2        3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3         3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4    42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
# ..               ...                 ...     ...               ...
# 657           Zivity          zivity.com     $8M         TC40 2007
# 658           Zmorph        zmorph3d.com     $1M                 -
# 659           Zocdoc          zocdoc.com   $223M         TC40 2007
# 660             Zula         zulaapp.com   $3.4M   Disrupt SF 2013
# 661           Zumper          zumper.com  $31.5M   Disrupt SF 2012
#
#               Result OperatingState
# 0         Contestant      Operating
# 1         Contestant         Closed
# 2         Contestant      Operating
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Startup         662 non-null    object
#  1   Product         656 non-null    object
#  2   Funding         448 non-null    object
#  3   Event           662 non-null    object
#  4   Result          662 non-null    object
#  5   OperatingState  662 non-null    object
# dtypes: object(6)
# memory usage: 31.2+ KB

# %%
# Shape of database

data1.shape
# Out:
# (662, 6)

# %%
data1.head()
# Out:
#            Startup             Product Funding             Event  \
# 0           2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1             3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2      3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3       3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4  42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
#
#             Result OperatingState
# 0       Contestant      Operating
# 1       Contestant         Closed
# 2       Contestant      Operating
# 3  Audience choice      Operating
# 4       Contestant      Operating

# %% [markdown]
# 2. Data exploration:
#
# • Check the datatypes of each attribute.
#
# • Check for null values in the attributes.

# %%
# 2. Date Exploration :
# i) Check data types of each attributes
# data types of each column

data1.dtypes.to_frame(name = 'Data Type')
# Out:
#                Data Type
# Startup           object
# Product           object
# Funding           object
# Event             object
# Result            object
# OperatingState    object

# %%
# 2. Date Exploration :
# ii)   Check null values in the attributes.

print(data1.isnull().any())
# Out:
# Startup           False
# Product            True
# Funding            True
# Event             False
# Result            False
# OperatingState    False
# dtype: bool

# %%
data1.isnull().sum()
# Out:
# Startup             0
# Product             6
# Funding           214
# Event               0
# Result              0
# OperatingState      0
# dtype: int64

# %% [markdown]
# 3. Data preprocessing & visualisation:
# • Drop the null values.
# • Convert the ‘Funding’ features to a numerical value.
# • Plot box plot for funds in million.
# • Get the lower fence from the box plot.
# • Check number of outliers greater than upper fence.
# • Drop the values that are greater than upper fence.
# • Plot the box plot after dropping the values.
# • Check frequency of the OperatingState features classes.
# • Plot a distribution plot for Funds in million.
# • Plot distribution plots for companies still operating and companies that closed.

# %%
# 3. Data preprocessing & visualisation:
# i) Drop the null values

df = data1.dropna()

# %%
df.shape
# Out:
# (446, 6)

# %%
df = df.reset_index(drop = True)
df
# Out:
#           Startup          Product Funding                      Event  \
# 0            3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 1      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 2            5to1         5to1.com  $19.3M                  TC50 2009
# 3    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 4      AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# ..            ...              ...     ...                        ...
# 441        Zivity       zivity.com     $8M                  TC40 2007
# 442        Zmorph     zmorph3d.com     $1M                          -
# 443        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 444          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 445        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState
# 0         Contestant         Closed
# 1    Audience choice      Operating
# ...

# %%
# 3. 3. Data preprocessing & visualisation:
# ii) Convert the ‘Funding’ features to a numerical value.

df.loc[:,'Funds_in_million'] = df['Funding'].apply(lambda x: float(x[1:-1])/1000 if x[-1] == 'K' else (float(x[1:-1])*1000 if x[-1] == 'B' else float(x[1:-1])))
df
# Out:
#           Startup          Product Funding                      Event  \
# 0            3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 1      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 2            5to1         5to1.com  $19.3M                  TC50 2009
# 3    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 4      AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# ..            ...              ...     ...                        ...
# 441        Zivity       zivity.com     $8M                  TC40 2007
# 442        Zmorph     zmorph3d.com     $1M                          -
# 443        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 444          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 445        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState  Funds_in_million
# 0         Contestant         Closed              0.63
# ...

# %%
# Plot box plot for funds in million.
plot = plt.boxplot(df.Funds_in_million)
plt.title('Boxplot of the funds')
plt.ylabel("Funding (in Million)")
plt.show()

# %%
# Get the lower fence from the box plot
Q1 = df["Funds_in_million"].quantile(0.25)

Q3 = df["Funds_in_million"].quantile(0.75)

IQR = Q3 - Q1
lower_Fence = Q1 - (1.5 * IQR)
lower_Fence
# Out:
# -12.349374999999998

# %%
# Check number of outliers greater than upper fence.

upper_fence = Q3 + (1.5 * IQR)
upper_fence
# Out:
# 22.569625

# %%
print(f'Number of outliers = {len(df[df.Funds_in_million > upper_fence])}') # Check number of outliers greater than upper fence.
# Out:
# Number of outliers = 60

# %%
df[df.Funds_in_million > upper_fence]
# Out:
#                Startup               Product  Funding  \
# 3         8 Securities       8securities.com     $29M
# 16             Anyclip           anyclip.com     $24M
# 21               Artsy             artsy.net   $50.9M
# 27          Badgeville        badgeville.com     $40M
# 33          Betterment        betterment.com    $205M
# 67           Clickable         clickable.com   $32.5M
# 71          Cloudflare        cloudflare.com  $182.1M
# 82       Credit Sesame      creditsesame.com   $35.4M
# 84    CrowdFlower Inc.       crowdflower.com     $38M
# 85       Cubic Telecom      cubictelecom.com   $37.1M
# 87            DataSift          datasift.com     $72M
# 88              DataXu            dataxu.com     $64M
# 102            Dropbox           dropbox.com    $1.7B
# 111             Enigma             enigma.io   $34.6M
# 117       EverythingMe         everything.me   $35.5M
# 121            Famo.us               famo.us   $30.1M
# ...

# %%
df.drop(df[df.Funds_in_million > upper_fence].index, inplace = True) # Drop the values that are greater than upper fence.

# %%
# Plot the box plot after dropping the values.
plot = plt.boxplot(df.Funds_in_million)
plt.title('Boxplot of funds greater than upper fence in original funds')
plt.ylabel("Funds raised (in Million)")
plt.show()

# %%
df.OperatingState.value_counts()
# Out:
# Operating    275
# Closed        56
# Acquired      55
# Name: OperatingState, dtype: int64

# %%
# Plot a distribution plot for Funds in million.
sns.distplot(df.Funds_in_million)
plt.title('Distribution of funding across all companies')
plt.show()
# Out:
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.Funds_in_million.describe()
# Out:
# count    386.00000
# mean       3.72514
# std        4.73236
# min        0.00500
# 25%        0.60000
# 50%        1.70000
# 75%        5.00000
# max       22.00000
# Name: Funds_in_million, dtype: float64

# %%
# Plot distribution plots for companies still operating and companies that closed
fig, ax = plt.subplots(1, 2)

fig.set_figheight(5)
fig.set_figwidth(15)

sns.distplot(df.loc[df.OperatingState == 'Operating', 'Funds_in_million'], ax = ax[0])
sns.distplot(df.loc[df.OperatingState =='Closed', 'Funds_in_million'], ax = ax[1])

ax[0].set_title('distribution plot for companies still operating')
ax[1].set_title('distribution plot for companies that got closed')
plt.show()
# Out:
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 4. Statistical analysis:
# • Is there any significant difference between Funds raised by companies that are still operating vs companies that closed down?
# Write the null hypothesis and alternative hypothesis.
# Test for significance and conclusion
# • Make a copy of the original data frame.
# • Check frequency distribution of Result variable.
# • Calculate percentage of winners that are still operating and percentage of contestants that are still operating
# • Write your hypothesis comparing the proportion of companies that are operating between winners and contestants:
#      Write the null hypothesis and alternative hypothesis.
#      Test for significance and conclusion
# • Check distribution of the Event variable.
# • Select only the Event that has disrupt keyword from 2013 onwards.
# • Write and perform your hypothesis along with significance test comparing the funds raised by companies across
# NY, SF and EU events from
# 2013 onwards.
# • Plot the distribution plot comparing the 3 city events.

# %% [markdown]
# Question :  Is there any significant difference between Funds raised by companies that
# are still operating vs companies that closed down?
#
# Write the null hypothesis and alternative hypothesis. #Test for significance and conclusion
#
# Answer :
#
# Null hypothesis (Ho) : There is no difference between the two means
#
# Alternate hypothesis (Ha) : There is significant difference between the two means
#
# we want to compare the difference in means of the samples, we can use 2 sample t test

# %%
from scipy.stats import ttest_ind

sample1 = df.loc[df.OperatingState == 'Operating', 'Funds_in_million']
sample2 = df.loc[df.OperatingState =='Closed', 'Funds_in_million']

alpha = 0.05   # significance level of 5%

t_statistic, p_value = ttest_ind(sample1, sample2)

if p_value <= alpha:
    print(f'Since the p-value, {round(p_value, 3)} < {alpha} (alpha) the difference is significant and we reject the Null hypothesis')
else:
    print(f'''\t Since the p-value, {round(p_value,3)} > {alpha} (alpha) the difference is not significant and,
    \t we fail to reject the Null hypothesis''')
# Out:
# 	 Since the p-value, 0.193 > 0.05 (alpha) the difference is not significant and,
#     	 we fail to reject the Null hypothesis

# %% [markdown]
# From the tests above we found no evidence to state that the companies that have raised more money tend to suceed more or vice-versa

# %%
df1 = data1.copy() # Make a copy of the original data frame.
df1.head()
# Out:
#            Startup             Product Funding             Event  \
# 0           2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1             3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2      3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3       3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4  42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
#
#             Result OperatingState
# 0       Contestant      Operating
# 1       Contestant         Closed
# 2       Contestant      Operating
# 3  Audience choice      Operating
# 4       Contestant      Operating

# %%
# Check frequency distribution of Result variable.
df1.Result.value_counts()
# Out:
# Contestant         488
# Finalist            84
# Audience choice     41
# Winner              26
# Runner up           23
# Name: Result, dtype: int64

# %%
# Calculate percentage of winners that are still operating and percentage of contestants that are still operating
winners = df1.Result.value_counts()['Winner']
contestants = df1.Result.value_counts()['Contestant']

# %%
contestants_operating = df1.OperatingState[df1.Result == 'Contestant'].value_counts().loc['Operating']
winners_operating = df1.OperatingState[df1.Result == 'Winner'].value_counts().loc['Operating']

# %%
winners_operating/winners, contestants_operating/contestants
# Out:
# (0.7307692307692307, 0.680327868852459)

# %% [markdown]
# Question :
# Write your hypothesis comparing the proportion of companies that are operating between winners and contestants:
# Write the null hypothesis and alternative hypothesis.
# Test for significance and conclusion
# Answer :
# - Z-test for proportions
# Null hyputhesis (Ho): The proportion of companies that are operating is the same in both categories - winners and contestants
#
# Alternative hypothesis (Ha): The proportion of companies that are operating is significantly different from each other, among the two categories

# %%
from statsmodels.stats.proportion import proportions_ztest

t_statistic, p_value = proportions_ztest([contestants_operating, winners_operating], [contestants, winners])

if p_value <= alpha:
    print(f'Since the p-value, {round(p_value, 3)} < {alpha} (alpha) the difference is significant and we reject the Null hypothesis')
else:
    print(f'''\t Since the p-value, {round(p_value,3)} > {alpha} (alpha) the difference is not significant and,
    \t we fail to reject the Null hypothesis''')
# Out:
# 	 Since the p-value, 0.59 > 0.05 (alpha) the difference is not significant and,
#     	 we fail to reject the Null hypothesis

# %% [markdown]
# The amount of funds a company raises is not a significant factor in deciding if the company will remain operational or close down

# %%
# Check distribution of the Event variable.
df.Event.value_counts()
# Out:
# TC50 2008                    25
# TC40 2007                    22
# Disrupt NY 2015              21
# Disrupt SF 2011              19
# Disrupt NYC 2013             19
# Disrupt SF 2013              19
# Disrupt NYC 2012             19
# Disrupt SF 2014              19
# TC50 2009                    19
# Disrupt SF 2015              19
# Disrupt SF 2016              17
# Disrupt NY 2016              16
# Disrupt NYC 2011             15
# Disrupt NYC 2014             15
# Disrupt SF 2012              15
# Disrupt SF 2010              13
# Hardware Battlefield 2016    12
# Hardware Battlefield 2014    12
# Disrupt London 2015          11
# Hardware Battlefield 2015    10
# Disrupt NYC 2010             10
# Disrupt EU 2014              10
# Disrupt London 2016          10
# Disrupt EU 2013               9
# -                             6
# Disrupt Beijing 2011          4
# Name: Event, dtype: int64

# %%
# Select only the Event that has disrupt keyword from 2013 onwards.
#df1[df1.Event.apply(lambda x: 'Disrupt' in x)].Event.value_counts()
events = df[df.Event.apply(lambda x: 'Disrupt' in x and int(x[-4:]) > 2012)].Event  # all the events of relevance
events
# Out:
# 0         Disrupt NYC 2013
# 1          Disrupt NY 2016
# 6          Disrupt SF 2015
# 7      Disrupt London 2016
# 9          Disrupt SF 2015
#               ...
# 427        Disrupt NY 2015
# 430       Disrupt NYC 2013
# 431        Disrupt SF 2014
# 435    Disrupt London 2015
# 444        Disrupt SF 2013
# Name: Event, Length: 185, dtype: object

# %%
NY_events = df.loc[events[events.apply(lambda x: 'NY' in x)].index, 'Funds_in_million']
SF_events = df.loc[events[events.apply(lambda x: 'SF' in x)].index, 'Funds_in_million']
EU_events = df.loc[events[events.apply(lambda x: 'EU' in x or 'London' in x)].index, 'Funds_in_million']
print(len(NY_events), len(SF_events), len(EU_events))
# Out:
# 71 74 40

# %% [markdown]
# Question :
# Write and perform your hypothesis along with significance test comparing the funds raised by companies across NY, SF and EU events from 2013 onwards.
# Answer :
# Null Hypothesis(Ho): Average funds raised by companies across three cities are the same
#
# Alternative Hypothesis(Ha): Average funds raised by companies across three cities are the different

# %%
from scipy.stats import f_oneway


stat, p_value = f_oneway(NY_events, SF_events, EU_events)

if p_value <= alpha:
    print(f'Since the p-value, {round(p_value, 3)} < {alpha} (alpha) the difference is significant and we reject the Null hypothesis')
else:
    print(f'''\t Since the p-value, {round(p_value,3)} > {alpha} (alpha) the difference is not significant and,
    \t we fail to reject the Null hypothesis''')
# Out:
# 	 Since the p-value, 0.628 > 0.05 (alpha) the difference is not significant and,
#     	 we fail to reject the Null hypothesis

# %% [markdown]
# The distribution of funds raised by the companies across the three regions is the same.
#
# We found no evidence to say companies participating in certain regions have funds either significantly on the higher side or on the lower side

# %%
#Plot the distribution plot comparing the 3 city events.
plt.figure(figsize=(15,6))
sns.distplot(NY_events, color = 'Red', label = 'NY')
sns.distplot(SF_events, color = 'Gold', label = 'SF')
sns.distplot(EU_events, color = 'blue', label = 'EU')
plt.legend()
plt.show()
# Out:
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\vrushali\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# 5. Write your observations on improvements or suggestions on quality, quantity, variety, velocity, veracity etc.
# on the data points collected to perform a better data analysis.

# %% [markdown]
# Quality : Data quality issues in Big Data is that the data includes several data types ( such as : structured, semi-structured, and unstructured) coming in from different data sources. Thus, often a single data quality metric will not be applicable for the entire data and so we need to separately define data quality metrics for each data type.
# Data that's of poor quality can increase data management costs as a result of frequent remediation, additional resource needs and compliance issues. It can also lead to impaired decision-making and business forecasting.

# %% [markdown]
# Quantity : The main characteristic that makes data “big” is the sheer volume. It makes no sense to focus on minimum storage units because the total amount of information is growing exponentially every year.No one really knows how much new data is being generated, but the amount of information being collected is huge.
# This volume presents the most immediate challenge to conventional IT structures. It calls for scalable storage, and a distributed approach to querying. Many companies already have large amounts of archived data, perhaps in the form of logs, but not the capacity to process it.

# %% [markdown]
# Variety : Data from different sources often has serious semantic differences. For example, “profit” can have widely varied definitions across the business units of an organization or external agencies. Thus, the fields with identical names may not mean the same thing. This problem is made worse by the lack of adequate and consistent meta-data from each data source. In order to make sense of data, you need reliable metadata (such as to make sense of sales numbers from a store, you need other information such as date-time, items purchased, coupons used, etc.). Usually, a lot of these data sources are outside an organization and thus, it is very hard to ensure good metadata for such data.

# %% [markdown]
# Velocity : The tremendous pace of data generation and collection makes it incredibly hard to monitor data quality within a reasonable overhead on time and resources (storage, compute, human effort, etc.). So, by the time data quality assessment completes, the output might be outdated and of little use, particularly if the Big Data project is to serve any real-time or near real-time business needs. In such scenarios, we need to re-define data quality metrics so that they are relevant as well as feasible in the real-time context.

# %% [markdown]
# Veracity: Veracity, one of the most overlooked Big Data characteristics, is directly related to data quality, as it refers to the inherent biases, noise and abnormality in data. Because of veracity, the data values might not be exact real values, rather they might be approximations. In other words, the data might have some inherent impreciseness and uncertainty. Besides data inaccuracies, Veracity also includes data consistency (defined by the statistical reliability of data) and data trustworthiness (based on data origin, data collection and processing methods, security infrastructure, etc.). These data quality issues in turn impact data integrity and data accountability.
